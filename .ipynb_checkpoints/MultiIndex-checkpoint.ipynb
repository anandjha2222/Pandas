# %%
import pandas as pd

# %%
bigmac = pd.read_csv('resources/bigmac.csv', parse_dates=['Date'])
bigmac.head()
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35
# 3 2016-01-01    Britain                 4.22
# 4 2016-01-01     Canada                 4.14

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# <h3>Create a MultiIndex with the set_index() Method</h3>

# %%
bigmac.set_index(keys = ['Date','Country'], inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.sort_index(inplace=True)

bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index

output = None

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %% [markdown]
# <h3>The .get_level_values() Method</h3>

# %%
bigmac = pd.read_csv('resources/bigmac.csv', parse_dates=['Date'], index_col=['Date','Country'])
bigmac.sort_index(inplace=True) # Best practice, as any method call will be faster
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.get_level_values(0)[:10]
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
bigmac.index.get_level_values('Country')[:10]
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic'],
#       dtype='object', name='Country')

# %% [markdown]
# <h3>The .set_names() Method</h3>

# %%
bigmac = pd.read_csv('resources/bigmac.csv', parse_dates=['Date'], index_col=['Date','Country'])
bigmac.sort_index(inplace=True) # Best practice, as any method call will be faster
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.set_names(['Day','Location'], inplace=True)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %% [markdown]
# <h3>The sort_index() Method</h3>

# %%
bigmac.sort_index(ascending=[True, False], inplace=True)
bigmac.head()
# Out:
#                           Price in US Dollars
# Day        Location
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83
#            UAE                           2.99
#            Turkey                        3.83

# %% [markdown]
# <h3>Extract Rows from a MultiIndex DataFrame</h3>

# %%
bigmac = pd.read_csv('resources/bigmac.csv', parse_dates=['Date'], index_col=['Date','Country'])
bigmac.sort_index(inplace=True) # Best practice, as any method call will be faster
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.loc[('2010-01-01')].head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.loc[('2010-01-01','Brazil')]
# Out:
# Price in US Dollars    4.76
# Name: (2010-01-01 00:00:00, Brazil), dtype: float64

# %%
bigmac.loc[('2010-01-01','Brazil'), 'Price in US Dollars']
# Out:
# Date        Country
# 2010-01-01  Brazil     4.76
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.loc[('2015-07-01', 'Chile') , 'Price in US Dollars']
# Out:
# Date        Country
# 2015-07-01  Chile      3.27
# Name: Price in US Dollars, dtype: float64

# %% [markdown]
# <h3>The .transpose() Method and MultiIndex on Column Level</h3>

# %%
bigmac = pd.read_csv('resources/bigmac.csv', parse_dates=['Date'], index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac = bigmac.transpose()
bigmac
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc['Price in US Dollars', ('2010-01-01')]
# Out:
# Date        Country
# 2010-01-01  Argentina         1.84
#             Australia         3.98
#             Brazil            4.76
#             Britain           3.67
#             Canada            3.97
#             Chile             3.18
#             China             1.83
#             Colombia          3.91
#             Costa Rica        3.52
#             Czech Republic    3.71
#             Denmark           5.99
#             Egypt             2.38
#             Euro area         4.84
#             Hong Kong         1.91
#             Hungary           3.86
#             Indonesia         2.24
#             Israel            3.99
#             Japan             3.50
#             Latvia            3.09
#             Lithuania         2.87
#             Malaysia          2.08
#             Mexico            2.50
#             New Zealand       3.61
#             Norway            7.02
#             Pakistan          2.42
#             Peru              2.81
# ...

# %%
bigmac.loc['Price in US Dollars', ('2010-01-01','Denmark')]
# Out:
# Date        Country
# 2010-01-01  Denmark    5.99
# Name: Price in US Dollars, dtype: float64

# %% [markdown]
# <h3>The .swaplevel() Method</h3>

# %%
bigmac = pd.read_csv('resources/bigmac.csv', parse_dates=['Date'], index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac = bigmac.swaplevel()

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2010-01-01                 1.84
# Australia 2010-01-01                 3.98
# Brazil    2010-01-01                 4.76
# Britain   2010-01-01                 3.67
# Canada    2010-01-01                 3.97

# %% [markdown]
# <h3>The .stack() Method</h3>

# %%
world = pd.read_csv('resources/worldstats.csv', index_col=['country', 'year'])
world.head()
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12

# %%
world.stack()

output= None

# %%
type(world.stack())
# Out:
# pandas.core.series.Series

# %%
world = world.stack().to_frame() # Incase you prefer DataFrame over Series

world.head()
# output = None
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08

# %%
world.rename(columns={0:'Stacked stat'}, inplace=True)
world.head()
# Out:
#                             Stacked stat
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08

# %% [markdown]
# <h3>The .unstack() Method</h3>

# %%
world = pd.read_csv('resources/worldstats.csv', index_col=['country', 'year'])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s = s.unstack().unstack().unstack()

s.head(10)
# Out:
#             year  country
# Population  1960  Afghanistan             8994793.0
#                   Albania                       NaN
#                   Algeria                11124892.0
#                   Andorra                       NaN
#                   Angola                        NaN
#                   Antigua and Barbuda           NaN
#                   Arab World                    NaN
#                   Argentina                     NaN
#                   Armenia                       NaN
#                   Aruba                         NaN
# dtype: float64

# %%
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(0)

output = None

# %%
s.unstack(1)

output = None

# %%
s.unstack(2)

output = None

# %%
s.unstack(-1).head()
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08

# %%
world = pd.read_csv('resources/worldstats.csv', index_col=['country', 'year'])
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(level=[1,0])

output = None

# %%
s.unstack(level=[0,1])

output = None

# %% [markdown]
# <h3>The .pivot() Method</h3>

# %%
sales = pd.read_csv('resources/salesmen.csv', parse_dates=['Date'])
sales['Salesman'] = sales['Salesman'].astype('category')
sales.head()
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982
# 3 2016-01-04      Bob     7917
# 4 2016-01-05      Bob     7837

# %%
len(sales)
# Out:
# 1830

# %%
sales['Salesman'].value_counts()
# Out:
# Ronald    366
# Oscar     366
# Jeb       366
# Dave      366
# Bob       366
# Name: Salesman, dtype: int64

# %%
sales.pivot(index='Date', columns="Salesman", values='Revenue').head()
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771

# %% [markdown]
# <h3>The .pivot_table() Method</h3>

# %%
foods = pd.read_csv('resources/foods.csv')
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
foods.pivot_table(values='Spend', index='Gender', aggfunc='mean')
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values='Spend', index='Gender', aggfunc='sum')
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
foods.pivot_table(values='Spend', index='Item', aggfunc='sum')
# Out:
#              Spend
# Item
# Burger     7765.73
# Burrito    8270.44
# Chalupa    7644.52
# Donut      8758.76
# Ice Cream  8886.99
# Sushi      8742.93

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], aggfunc='sum')
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], columns='City' ,aggfunc='sum')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], columns=['Frequency','City'] ,aggfunc='sum')
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger      262.67       231.68   144.66   171.86       215.05
#        Burrito     224.45       321.57   195.63   122.74        34.28
#        Chalupa      43.19        23.49    95.70   158.37       289.96
#        Donut       478.10       247.40   124.35   284.53        50.25
#        Ice Cream   262.19       177.69    92.88    92.53        74.51
#        Sushi        81.07       348.53   393.27    93.16        78.71
# Male   Burger      319.46       112.70   197.72   187.29       213.14
#        Burrito     236.21       165.76   276.23   147.54        89.58
#        Chalupa      54.09       274.81   192.64   333.76        90.70
#        Donut       230.00       190.71   129.42   183.73       259.29
#        Ice Cream   178.22       148.69    15.17   152.20       386.55
# ...

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], columns='City' ,aggfunc='count')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger           24            31        27
#        Burrito          23            28        34
#        Chalupa          19            32        25
#        Donut            31            30        34
#        Ice Cream        27            32        22
#        Sushi            31            30        32
# Male   Burger           22            21        31
#        Burrito          25            30        28
#        Chalupa          25            23        23
#        Donut            30            33        29
#        Ice Cream        29            41        25
#        Sushi            27            28        18

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], columns='City' ,aggfunc='max')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger        98.96         97.79     85.06
#        Burrito       92.25         96.79     99.21
#        Chalupa       98.43         99.29     98.78
#        Donut         95.63         96.52     91.75
#        Ice Cream     97.83         88.14     97.44
#        Sushi         99.51         99.02     95.43
# Male   Burger        90.32         99.68     97.20
#        Burrito       98.04         93.27     95.07
#        Chalupa       96.44         98.40     99.87
#        Donut         86.70         93.12     99.26
#        Ice Cream     97.65         99.24     99.17
#        Sushi         93.85         97.12     98.48

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], columns='City' ,aggfunc='min')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger         2.25          1.97      6.24
#        Burrito        1.02          1.04      1.18
#        Chalupa        1.96          9.35      9.09
#        Donut          3.15          2.13      1.68
#        Ice Cream     13.39          7.61      8.80
#        Sushi          2.52         11.68      8.20
# Male   Burger         5.43          1.71      2.83
#        Burrito       15.90          8.58      3.64
#        Chalupa       11.61          1.94     10.56
#        Donut          1.49          1.26      6.63
#        Ice Cream     14.06          4.89      3.43
#        Sushi          3.28          2.01     32.15

# %%
pd.pivot_table(data= foods,values='Spend', index=['Gender','Item'], columns='City' ,aggfunc='min')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger         2.25          1.97      6.24
#        Burrito        1.02          1.04      1.18
#        Chalupa        1.96          9.35      9.09
#        Donut          3.15          2.13      1.68
#        Ice Cream     13.39          7.61      8.80
#        Sushi          2.52         11.68      8.20
# Male   Burger         5.43          1.71      2.83
#        Burrito       15.90          8.58      3.64
#        Chalupa       11.61          1.94     10.56
#        Donut          1.49          1.26      6.63
#        Ice Cream     14.06          4.89      3.43
#        Sushi          3.28          2.01     32.15

# %% [markdown]
# <h3>The pd.melt() Method</h3>
#
# reverse of pivot_table() method

# %%
sales = pd.read_csv('resources/quarters.csv')

# %%
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(frame=sales, id_vars='Salesman', var_name='Quarter', value_name='Revenue')
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
