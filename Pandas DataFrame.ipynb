# %%
import pandas as pd
import numpy as np

# %%
nba = pd.read_csv('resources/nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# NOTE:
#     1. NaN stands for Blank or null or missinh or empty value
#     2. Age, Weight , Height columns are stored as integers inside csv file, BUT whenever pandas find a NaN values, it convert int to float

# %% [markdown]
# <h3>Shared Methods and Attributes between Series and DataFrames</h3>

# %%
nba.head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
nba.tail(1)
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN

# %%
nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# <h3>Differences between identical methods</h3>

# %%
rev = pd.read_csv('resources/revenue.csv', index_col='Date')
s =  pd.Series([1,2,3,4,5])
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
s.sum()
# Out:
# 15

# %%
rev.sum(axis=1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# <h3>Select One Column from a DataFrame</h3>
#
# Return type will be a Series

# %% [markdown]
# Below syntax will work only with valid python identifier, hence less preferable

# %%
nba.Name
nba.Number
nba.Salary

Output= None

# %% [markdown]
# Below will work all the time

# %%
nba['Name']
nba['Number']
nba['Salary']

Output=None

# %% [markdown]
# <h3>Select Two or More Columns from a DataFrame</h3>
#
# Return type will be a DataFrame

# %%
nba[['Team','Name']].head(3)
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland

# %% [markdown]
# <h3>Add New Column to DataFrame</h3>

# %%
nba['Sport'] = "Basketball"
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba['League'] = 'National Basketball association'
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                           League
# 0              Texas  7730337.0  Basketball  National Basketball association
# 1          Marquette  6796117.0  Basketball  National Basketball association
# 2  Boston University        NaN  Basketball  National Basketball association

# %% [markdown]
# Below is another syntax to do the same

# %%
nba = pd.read_csv('resources/nba.csv')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.insert(9, "Sport", "Basketball")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba.insert(7,"League","National Basketball association")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#                             League            College     Salary       Sport
# 0  National Basketball association              Texas  7730337.0  Basketball
# 1  National Basketball association          Marquette  6796117.0  Basketball
# 2  National Basketball association  Boston University        NaN  Basketball

# %% [markdown]
# <h3>Broadcasting Operation</h3>

# %%
nba = pd.read_csv('resources/nba.csv')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Age"].add(5).head()

# OR

# nba['Age'] + 5
# Out:
# 0    30.0
# 1    30.0
# 2    32.0
# 3    27.0
# 4    34.0
# Name: Age, dtype: float64

# %%
nba["Salary"].sub(50000).head()

# OR

# nba["Salary"] - 50000
# Out:
# 0    7680337.0
# 1    6746117.0
# 2          NaN
# 3    1098640.0
# 4    4950000.0
# Name: Salary, dtype: float64

# %%
nba['Weight in KG'] = nba['Weight'] * 0.453592
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in KG
# 0              Texas  7730337.0      81.64656
# 1          Marquette  6796117.0     106.59412
# 2  Boston University        NaN      92.98636

# %% [markdown]
# <h3>Review of value_count() method</h3>
#
# value_count() method is only available for Pandas Series.

# %%
nba = pd.read_csv('resources/nba.csv')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba['Team'].value_counts().head(2)
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# Name: Team, dtype: int64

# %%
nba['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba['Weight'].value_counts().tail()
# Out:
# 278.0    1
# 227.0    1
# 239.0    1
# 289.0    1
# 307.0    1
# Name: Weight, dtype: int64

# %% [markdown]
#  <h3>Drop Rows with null Values</h3>

# %%
nba = pd.read_csv('resources/nba.csv')
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna(how='all', inplace=True) # how='any'
#use inplace to make change permanent inplace

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(axis=1).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0

# %%
nba.dropna(subset=['Salary','College'])

output=None

# %% [markdown]
# <h3>Fill in Null Values with the .fillna() Method</h3>
#
# applpying fillna() on DataFrame as a whole won't make sence in most cases because of difference in data tyes of columns. Instead apply fillna() on Series extracted from DataFrame

# %%
nba = pd.read_csv('resources/nba.csv')

# %%
nba['Salary'].fillna(0,inplace=True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['College'].fillna("No College", inplace=True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# <h3>astype() method</h3>
#
# Converts data type of a series from one type to another. It requires a Series to not have any null values.

# %%
nba= pd.read_csv('resources/nba.csv').dropna(how='all')
nba['Salary'].fillna(0, inplace= True)
nba['College'].fillna('No College', inplace=True)

nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %%
# nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba['Salary'] = nba['Salary'].astype('int64') # we dont have inplace parameter here

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba['Number'] = nba['Number'].astype('int')

# %%
nba['Age'] = nba['Age'].astype('int')

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %% [markdown]
# **category type reduces memory usage drastically. It is used if a column have a limited certail type of values like week name, month name etc**

# %%
nba['Position'] = nba['Position'].astype('category')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int64
# dtypes: category(1), float64(1), int32(2), int64(1), object(4)
# memory usage: 29.2+ KB

# %%
nba['Position'].nunique()
# Out:
# 5

# %% [markdown]
# <h3>Sort a DataFrame with the .sort_values() Method</h3>

# %%
nba = pd.read_csv('resources/nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values("Name", ascending=False)
nba.sort_values("Age", ascending=False)


output=None

# %%
nba.sort_values("Salary", na_position= 'first').head(10)
# Out:
#                Name                 Team  Number Position   Age Height  \
# 2      John Holland       Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford    Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson    Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber           Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright           Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane       Denver Nuggets     6.0       SG  23.0    6-7
#
#      Weight                College  Salary
# 2     205.0      Boston University     NaN
# 46    254.0                   Duke     NaN
# 171   225.0                   Duke     NaN
# ...

# %%
nba.sort_values(['Team','Name'], ascending=[True,False], inplace=True)

# %%
nba.head()
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
# 320   Thabo Sefolosha  Atlanta Hawks    25.0       SF  32.0    6-7   220.0
# 315      Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
#
#             College      Salary
# 322             NaN   1000000.0
# 310        Michigan   1304520.0
# 321             NaN   9756250.0
# 320             NaN   4000000.0
# 315  Louisiana Tech  18671659.0

# %% [markdown]
# <h3>Sort DataFrame with the .sort_index() Method</h3>

# %%
nba = pd.read_csv('resources/nba.csv')

# first lets jumble

nba.sort_values(['Number','Salary','Name'], inplace=True)
nba.head(10)
# Out:
#                  Name                  Team  Number Position   Age Height  \
# 291   Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0    6-5
# 248  Andrew Goudelock       Houston Rockets     0.0       PG  27.0    6-3
# 347   Josh Richardson            Miami Heat     0.0       SG  22.0    6-6
# 266    JaMychal Green     Memphis Grizzlies     0.0       PF  25.0    6-9
# 47      Isaiah Canaan    Philadelphia 76ers     0.0       PG  25.0    6-0
# 22       Shane Larkin         Brooklyn Nets     0.0       PG  23.0   5-11
# 152      Aaron Brooks         Chicago Bulls     0.0       PG  31.0    6-0
# 383    Darrell Arthur        Denver Nuggets     0.0       PF  28.0    6-9
# 393   Emmanuel Mudiay        Denver Nuggets     0.0       PG  20.0    6-5
# 188    Andre Drummond       Detroit Pistons     0.0        C  22.0   6-11
#
#      Weight           College     Salary
# 291   220.0  UC Santa Barbara    55722.0
# 248   200.0        Charleston   200600.0
# ...

# %%
nba.sort_index(ascending=False, inplace=True)

# %%
nba.head()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0
# 454   900000.0
# 453  2433333.0

# %% [markdown]
# <h3>Rank Values with the .rank() Method</h3>
#
# Can be called on a Series to generate a brand new series of Rank
#
# NOTE : First get rid of null values in the DataFrame

# %%
nba = pd.read_csv('resources/nba.csv').dropna(how='all')
nba['Salary'] = nba['Salary'].fillna(0).astype('int')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %% [markdown]
# Lets say we want to give 1 to the player having highest salary and so on..

# %%
nba['Salary Rank'] = nba["Salary"].rank(ascending=False).astype('int')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452

# %%
nba.sort_values(by='Salary', ascending=False).head(5)

# Check the salary and rank assigned
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
#
#      Weight       College    Salary  Salary Rank
# 109   212.0           NaN  25000000            1
# 169   250.0           NaN  22970500            2
# 33    240.0      Syracuse  22875000            3
# 251   265.0           NaN  22359364            4
# 339   235.0  Georgia Tech  22192730            5

# %% [markdown]
# <h2>Filtering DataFrame</h2>

# %% [markdown]
# Lets import and clean our DatFrame first<br>
#
# Cleaning that we will do is:
#     1. convert 'Start Date' and 'Last Login Time' as date_time because these are just in string format
#     2. Convert type of 'Senior Management' and 'Gender' columns to reduce memory usage

# %%
df = pd.read_csv('resources/employees.csv', parse_dates=['Start Date', 'Last Login Time'])

# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# Parsing columns seperately to datetime is not a very efficient technique. Instead, use 'parse_dates' attribute of read_csv()


df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-05-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-05-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-05-06 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2020-05-06 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2020-05-06 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df['Start Date'].head()
# Out:
# 0   1993-08-06
# 1   1996-03-31
# 2   1993-04-23
# 3   2005-03-04
# 4   1998-01-24
# Name: Start Date, dtype: datetime64[ns]

# %%
# df['Start Date'] = pd.to_datetime(df['Start Date'])

# df['Start Date'].head()

# %%
# df['Last Login Time'].head()

# %%
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
# df['Last Login Time'].head()

# %% [markdown]
# *NOTE* : Along with time, today's date is algo getting added.

# %%
# df['Senior Management'] = df['Senior Management'].astype('bool')

# %%
# df['Gender'] = df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# <h3>Filter a DataFrame Based on A Condition</h3>

# %%
df[df['Gender'] == 'Male']
output = None

# %%
df[df['Team']=='Finance']
output = None

# %%
df[df['Senior Management']]
output = None

# %%
mask =df['Team'] != 'Marketing'

df[mask]
output = None

# %%
df[df['Salary'] > 110000]
output = None

# %%
df[df['Start Date'] <= '1985-01-01'].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10     Louise  Female 1980-08-12 2020-05-06 09:01:00   63241   15.132
# 12    Brandon    Male 1980-12-01 2020-05-06 01:08:00  112807   17.492
# 18      Diana  Female 1981-10-23 2020-05-06 10:27:00  132940   19.082
# 28      Terry    Male 1981-11-27 2020-05-06 18:30:00  124008   13.464
# 37      Linda  Female 1981-10-19 2020-05-06 20:49:00   57427    9.557
#
#     Senior Management             Team
# 10               True              NaN
# 12               True  Human Resources
# 18              False  Client Services
# 28               True  Client Services
# 37               True  Client Services

# %%
mask1 = df['Gender'] == 'Male'
mask2 = df['Team'] == 'Marketing'

df[mask1 & mask2].head(3)
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2020-05-06 12:42:00   97308    6.945
# 21    Matthew   Male 1995-09-05 2020-05-06 02:12:00  100612   13.645
# 26      Craig   Male 2000-02-27 2020-05-06 07:45:00   37598    7.757
#
#     Senior Management       Team
# 0                True  Marketing
# 21              False  Marketing
# 26               True  Marketing

# %%
mask1 = df['Senior Management']
mask2 = df['Start Date'] < '1990-01-01'

df[mask1 | mask2].tail()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 992    Anthony    Male 2011-10-16 2020-05-06 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-05-06 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-05-06 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-05-06 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2020-05-06 18:24:00  129949   10.169
#
#      Senior Management         Team
# 992               True      Finance
# 993               True  Engineering
# 994               True    Marketing
# 996              False      Finance
# 999               True        Sales

# %%
mask1 = df['First Name'] == 'Robert'
mask2 = df['Team'] == 'Client Services'
mask3 = df['Start Date'] > '2016-06-01'

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2020-05-06 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2020-05-06 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2020-05-06 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2020-05-06 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# <h3>The isin() method</h3>

# %%
mask = df['Team'].isin(['Legal','Sales','Product','Marketing'])
df[mask]

output = None

# %% [markdown]
# <h3>The .isnull() and .notnull() Methods</h3>

# %%
df[df['Team'].isnull()]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2020-05-06 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2020-05-06 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2020-05-06 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2020-05-06 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2020-05-06 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2020-05-06 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2020-05-06 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2020-05-06 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2020-05-06 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2020-05-06 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2020-05-06 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2020-05-06 06:06:00   66067   10.957
# ...

# %%
df[df['Gender'].notnull()].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-05-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-05-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-05-06 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2020-05-06 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2020-05-06 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# <h3>The .between() Method</h3>

# %%
df[df['Salary'].between(80000,90000)]

output = None

# %%
df[df['Bonus %'].between(2.0, 5.0)]
output = None

# %%
df[df['Start Date'].between('1991-01-01','1992-01-01')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2020-05-06 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2020-05-06 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2020-05-06 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2020-05-06 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2020-05-06 02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09 2020-05-06 18:52:00   42341    7.014
# 172       Sara  Female 1991-09-23 2020-05-06 18:17:00   97058    9.402
# 220        NaN  Female 1991-06-17 2020-05-06 12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11 2020-05-06 07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29 2020-05-06 06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01 2020-05-06 02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19 2020-05-06 02:54:00   76076    5.319
# ...

# %%
df[df['Last Login Time'].between('08:30AM','12:00PM')]
output = None

# %% [markdown]
# <h3>The .duplicated() Method</h3>

# %%
df.sort_values('First Name', inplace=True)

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-05-06 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-05-06 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-05-06 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2020-05-06 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2020-05-06 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df[df['First Name'].duplicated()]

# this method has keep parameter, we can pass 'last', 'first', False

output = None

# %%
df[~df['First Name'].duplicated(keep= False)]

# output = None
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-05-06 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-05-06 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-05-06 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-05-06 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-05-06 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-05-06 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-05-06 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-05-06 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-05-06 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %% [markdown]
# <h3>The drop_duplicates() Method</h3>

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-05-06 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-05-06 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-05-06 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2020-05-06 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2020-05-06 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates()) # Means - duplicate did not get removed

# works if whole row matches
# Out:
# 1000

# %%
df.drop_duplicates(subset=['First Name'], keep='first')

output = None

# %%
df.drop_duplicates(subset=['First Name'], keep='last')

output = None

# %%
df.drop_duplicates(subset=['First Name'], keep=False)

output = None

# %%
df.drop_duplicates(subset=['Team'], keep=False)

# output = None
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
df.drop_duplicates(subset=['First Name', 'Team'], inplace=True)

len(df)
# Out:
# 769

# %% [markdown]
# <h3>The .unique() and .nunique() Methods</h3>
#
# Workd on Series

# %%
df = pd.read_csv('resources/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-05-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-05-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-05-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df['Gender'].unique()
# Out:
# [Male, Female, NaN]
# Categories (2, object): [Male, Female]

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Team'].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
len(df['Team'].unique())
# Out:
# 11

# %%
df['Team'].nunique() # automatically drops null values
# Out:
# 10

# %%
df['Team'].nunique(dropna=False)
# Out:
# 11

# %% [markdown]
# **Let's now work with other data**

# %%
bond = pd.read_csv('resources/jamesbond.csv')
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %% [markdown]
# <h3>The .set_index() and .reset_index() Methods</h3>
#
# set_index() is an alternative to inex_col parameter to read_csv method and many more<br>
#
# reset_index() move back the column that we set as index and assign default index to DataFrame

# %%
bond.set_index('Film', inplace=True)
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(inplace=True, drop=False)
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# NOTE : lets you set your index as 'Film' and again set as 'Year', 'Film' column will be removed from the DataFrame so be causious here, hence do reset_index first

# %% [markdown]
# <h3>Retrieve Rows by Index Label with .loc[]</h3>
#
# NOTE : If your index is sorted, subsequent operation will be fast

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['Goldfinger']
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
# bond.loc['Some Unknown key']

# %% [markdown]
# **Pandas DataFrame need not to have unique value in Key unlike Python Dictionary**

# %%
bond.loc['Diamonds Are Forever' : 'Moonraker']
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# ...

# %%
bond.loc['GoldenEye' :]
# Out:
#                                  Year           Actor            Director  \
# Film
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# ...

# %%
bond.loc[['Moonraker','Octopussy']]
# Out:
#            Year        Actor       Director  Box Office  Budget  \
# Film
# Moonraker  1979  Roger Moore  Lewis Gilbert       535.0    91.5
# Octopussy  1983  Roger Moore      John Glen       373.8    53.9
#
#            Bond Actor Salary
# Film
# Moonraker                NaN
# Octopussy                7.8

# %%
'DDLJ' in bond.index
# Out:
# False

# %% [markdown]
# <h3>Retrieve Rows by Index Position with .iloc[]</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv')
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.iloc[15]
bond.loc[15]
# both will be same as we have numeric index here
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[[15,20]]
bond.iloc[:4]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
bond.iloc[4:8]
# Out:
#                               Film  Year           Actor       Director  \
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6
# 7       442.5    34.7                5.8

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[5:6]
# Out:
#         Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No  1962  Sean Connery  Terence Young       448.8     7.0
#
#         Bond Actor Salary
# Film
# Dr. No                0.6

# %% [markdown]
# <h3>Set New Values for a Specific Cell or Row</h3>

# %%
bond.loc['Dr. No', "Actor"] = "Salmaan Khan"

# %%
bond.loc['Dr. No']
# Out:
# Year                          1962
# Actor                 Salmaan Khan
# Director             Terence Young
# Box Office                   448.8
# Budget                           7
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
bond.loc['Dr. No', ['Box Office','Budget','Bond Actor Salary']] = [448800000, 6000000,8000000]

# %%
bond.loc['Dr. No']
# Out:
# Year                          1962
# Actor                 Salmaan Khan
# Director             Terence Young
# Box Office               4.488e+08
# Budget                       6e+06
# Bond Actor Salary            8e+06
# Name: Dr. No, dtype: object

# %% [markdown]
# <h3>Set Multiple Values in DataFrame</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask = bond['Actor'] == 'Sean Connery'
bond.loc[mask, 'Actor'] = 'Sir Sean Connery' # this is view not a copy

# %%
bond['Actor']
# Out:
# Film
# A View to a Kill                        Roger Moore
# Casino Royale                          Daniel Craig
# Casino Royale                           David Niven
# Diamonds Are Forever               Sir Sean Connery
# Die Another Day                      Pierce Brosnan
# Dr. No                             Sir Sean Connery
# For Your Eyes Only                      Roger Moore
# From Russia with Love              Sir Sean Connery
# GoldenEye                            Pierce Brosnan
# Goldfinger                         Sir Sean Connery
# Licence to Kill                      Timothy Dalton
# Live and Let Die                        Roger Moore
# Moonraker                               Roger Moore
# Never Say Never Again              Sir Sean Connery
# Octopussy                               Roger Moore
# On Her Majesty's Secret Service      George Lazenby
# Quantum of Solace                      Daniel Craig
# Skyfall                                Daniel Craig
# ...

# %% [markdown]
# <h3>Rename Index Labels or Columns in a DataFrame</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.rename(columns={'Year' : 'Release Date', 'Box Office' : 'Revenue'}, inplace=True)

# %%
bond.head(1)
# Out:
#                   Release Date        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill          1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.rename(index={'Dr No':"Doctor No"  , 'GoldenEye':'Golden Eye'}, inplace=True)

# %%
bond.head(10)
# Out:
#                        Release Date           Actor         Director  Revenue  \
# Film
# A View to a Kill               1985     Roger Moore        John Glen    275.2
# Casino Royale                  2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                  1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever           1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day                2002  Pierce Brosnan     Lee Tamahori    465.4
# Dr. No                         1962    Sean Connery    Terence Young    448.8
# For Your Eyes Only             1981     Roger Moore        John Glen    449.4
# From Russia with Love          1963    Sean Connery    Terence Young    543.8
# Golden Eye                     1995  Pierce Brosnan  Martin Campbell    518.5
# Goldfinger                     1964    Sean Connery     Guy Hamilton    820.4
#
#                        Budget  Bond Actor Salary
# Film
# ...

# %%
bond.loc['Golden Eye']
# Out:
# Release Date                    1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Revenue                        518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: Golden Eye, dtype: object

# %% [markdown]
# NOTE : we can use column attribute of DataFrame also to rename the columns, BUT will have to pass all values as column and index is immutable

# %%
bond.columns
# Out:
# Index(['Release Date', 'Actor', 'Director', 'Revenue', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
bond.columns = ['Year of Release', 'Actor', 'Director', 'Gross', 'Budget', 'Salary']

# %%
bond.head()
# Out:
#                       Year of Release           Actor         Director  Gross  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen  275.2
# Casino Royale                    2006    Daniel Craig  Martin Campbell  581.5
# Casino Royale                    1967     David Niven       Ken Hughes  315.0
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton  442.5
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori  465.4
#
#                       Budget  Salary
# Film
# A View to a Kill        54.5     9.1
# Casino Royale          145.3     3.3
# Casino Royale           85.0     NaN
# Diamonds Are Forever    34.7     5.8
# Die Another Day        154.2    17.9

# %% [markdown]
# <h3>Delete Rows or Columns from a DataFrame</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.drop('A View to a Kill').head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                1962    Sean Connery    Terence Young       448.8
#
#                       Budget  Bond Actor Salary
# Film
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9
# Dr. No                   7.0                0.6

# %%
bond.drop(['Casino Royale', 'Die Another Day'], inplace=True)

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# A View to a Kill       1985   Roger Moore      John Glen       275.2    54.5
# Diamonds Are Forever   1971  Sean Connery   Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# For Your Eyes Only     1981   Roger Moore      John Glen       449.4    60.2
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
#
#                        Bond Actor Salary
# Film
# A View to a Kill                     9.1
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# For Your Eyes Only                   NaN
# From Russia with Love                1.6

# %%
bond.drop('Box Office', axis=1, inplace=True)

# %% [markdown]
# **pop() method on dataframe deletes column and returns that deleted column as Series**

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)

# %%
bond.pop('Actor')
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %%
del bond['Director']

# %%
del bond['Year']

# %%
bond.head()
# Out:
#                                Actor  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill         Roger Moore       275.2    54.5                9.1
# Casino Royale           Daniel Craig       581.5   145.3                3.3
# Casino Royale            David Niven       315.0    85.0                NaN
# Diamonds Are Forever    Sean Connery       442.5    34.7                5.8
# Die Another Day       Pierce Brosnan       465.4   154.2               17.9

# %% [markdown]
# <h3>Create Random Sample with the .sample() Method</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sample(n=2) # returns random sample , brand new DataFrame
# Out:
#                       Year           Actor       Director  Box Office  Budget  \
# Film
# Die Another Day       2002  Pierce Brosnan   Lee Tamahori       465.4   154.2
# The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0    45.1
#
#                       Bond Actor Salary
# Film
# Die Another Day                    17.9
# The Spy Who Loved Me                NaN

# %%
bond.sample(frac=.10)
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
# Goldfinger       1964    Sean Connery  Guy Hamilton       820.4    18.6
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9
# Octopussy                      7.8
# Goldfinger                     3.2

# %%
bond.sample(n=3 , axis=1)
# Out:
#                                  Year  Box Office           Actor
# Film
# A View to a Kill                 1985       275.2     Roger Moore
# Casino Royale                    2006       581.5    Daniel Craig
# Casino Royale                    1967       315.0     David Niven
# Diamonds Are Forever             1971       442.5    Sean Connery
# Die Another Day                  2002       465.4  Pierce Brosnan
# Dr. No                           1962       448.8    Sean Connery
# For Your Eyes Only               1981       449.4     Roger Moore
# From Russia with Love            1963       543.8    Sean Connery
# GoldenEye                        1995       518.5  Pierce Brosnan
# Goldfinger                       1964       820.4    Sean Connery
# Licence to Kill                  1989       250.9  Timothy Dalton
# Live and Let Die                 1973       460.3     Roger Moore
# Moonraker                        1979       535.0     Roger Moore
# ...

# %% [markdown]
# <h3>The .nsmallest() and .nlargest() Methods</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# Below is the brute force approach

# %%
bond.sort_values('Box Office', ascending=False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(n=3, columns='Box Office')
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(n=2, columns='Box Office')
# Out:
#                   Year           Actor   Director  Box Office  Budget  \
# Film
# Licence to Kill   1989  Timothy Dalton  John Glen       250.9    56.7
# A View to a Kill  1985     Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# Licence to Kill                 7.9
# A View to a Kill                9.1

# %%
bond.nlargest(3, columns='Budget')
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond.nsmallest(2, columns='Bond Actor Salary')
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %% [markdown]
# *Can be applied on Series as well*

# %%
bond['Box Office'].nlargest(4)
# Out:
# Film
# Skyfall        943.5
# Thunderball    848.1
# Goldfinger     820.4
# Spectre        726.7
# Name: Box Office, dtype: float64

# %%
bond['Year'].nsmallest(2)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Name: Year, dtype: int64

# %% [markdown]
# <h3>Filtering with the .where() Method</h3>
#
# Returns a complete DataFrame with actual data where condition matches and NaN where condition does not match

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask = bond['Actor'] == 'Sean Connery'

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
mask2 = bond['Box Office'] > 800
bond.where(mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
mask3 = bond['Budget'] > 40

bond.where(mask & mask2 & mask3)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                          NaN           NaN            NaN
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %% [markdown]
# <h3>The .query() Method</h3>
#
# This method works only when column name don't have space in bitween

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
bond.rename(columns={"Box Office":"Box_Office","Bond Actor Salary":"Bond_Actor_Salary"}, inplace=True)

# Pure Python Way

# bond.columns = [column_name.replace(" ","_") for column_name in bond.columns]


bond.head(1)
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %%
bond.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.query("Director == 'Terence Young'")
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Box_Office > 600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor == 'Roger Moore' and Director == 'John Glen' ")
# Out:
#                     Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond_Actor_Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8

# %% [markdown]
# <h3>A Review of the .apply() Method on Single Columns</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLIONS!"

# %%
# bond['Box Office'] = bond['Box Office'].apply(convert_to_string_and_add_millions)
# bond['Budget'] = bond['Budget'].apply(convert_to_string_and_add_millions)

# %%
columns = ['Box Office', "Budget", 'Bond Actor Salary']
for col in columns:
    bond[col] = bond[col].apply(convert_to_string_and_add_millions)

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director       Box Office  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen  275.2 MILLIONS!
# Casino Royale     2006  Daniel Craig  Martin Campbell  581.5 MILLIONS!
# Casino Royale     1967   David Niven       Ken Hughes  315.0 MILLIONS!
#
#                            Budget Bond Actor Salary
# Film
# A View to a Kill   54.5 MILLIONS!     9.1 MILLIONS!
# Casino Royale     145.3 MILLIONS!     3.3 MILLIONS!
# Casino Royale      85.0 MILLIONS!     nan MILLIONS!

# %% [markdown]
# <h3>The .apply() Method with Row Values</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    
    actor = row[1]
    budget = row[4]
    
    if actor == 'Pierce Brosnan':
        return "The Best"
    elif actor == "Rojer Moore" and budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"
    
bond.apply(good_movie, axis=1)
# Out:
# Film
# A View to a Kill                   I have no clue
# Casino Royale                      I have no clue
# Casino Royale                      I have no clue
# Diamonds Are Forever               I have no clue
# Die Another Day                          The Best
# Dr. No                             I have no clue
# For Your Eyes Only                 I have no clue
# From Russia with Love              I have no clue
# GoldenEye                                The Best
# Goldfinger                         I have no clue
# Licence to Kill                    I have no clue
# Live and Let Die                   I have no clue
# Moonraker                          I have no clue
# Never Say Never Again              I have no clue
# Octopussy                          I have no clue
# On Her Majesty's Secret Service    I have no clue
# Quantum of Solace                  I have no clue
# Skyfall                            I have no clue
# Spectre                            I have no clue
# ...

# %% [markdown]
# <h3>The .copy() Method</h3>

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond['Director']
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors['A View to a Kill'] = "Mister John Glen"
# Out:
# C:\Users\Anand\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor          Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mister John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven        Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# You can see that above operation changes the original DataFrame, sometime this is not the expected behaviour

# %%
bond = pd.read_csv('resources/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond['Director'].copy()
directors.head(1)
# Out:
# Film
# A View to a Kill    John Glen
# Name: Director, dtype: object

# %%
directors['A View to a Kill'] = " Minster John Glen"

directors.head(3)
# Out:
# Film
# A View to a Kill     Minster John Glen
# Casino Royale          Martin Campbell
# Casino Royale               Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
